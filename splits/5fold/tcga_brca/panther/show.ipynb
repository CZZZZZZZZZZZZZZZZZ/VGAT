# %%
import pickle

path = '/home/czz/pytorch_code/MSG2AT/MSG2AT-main/splits/RNA/tcga_blca/panther/4/prototypes/prototypes_c16_resnet50_20_faiss_num_1.0e+06.pkl'

with open(path, 'rb') as f:
    p_feature = pickle.load(f)

print(p_feature.keys())
print(p_feature['prototypes'].shape)
# Out:
# dict_keys(['prototypes'])
# (1, 16, 1024)
